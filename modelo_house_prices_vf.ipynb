# %% [markdown]
# ### Predição do **Preço de Casas** utilizando técnicas de **Regressão**
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# #### Introdução
# ##### O mercado imobiliário é uma das áreas mais dinâmicas da economia, sendo fortemente influenciado por diversos fatores, como localização, tamanho, infraestrutura e condições do imóvel. A previsão precisa do preço de uma casa é um desafio significativo, mas ao mesmo tempo, essencial para compradores, vendedores e investidores que buscam tomar decisões informadas.
#
# ##### Neste projeto, o objetivo é desenvolver um modelo de regressão capaz de predizer o preço de venda de imóveis residenciais. Para isso, utilizamos o dataset _House Prices: Advanced Regression Techniques_, disponível no Kaggle, que contém informações detalhadas sobre características dos imóveis, como área útil, número de quartos, tipo de material utilizado na construção, entre outros.
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Etapas do Projeto
#
# ##### 1. Exploração de Dados: Análise inicial dos dados, identificação de padrões e possíveis inconsistências.
# ##### 2. Pré-processamento: Tratamento de valores ausentes, remoção de outliers e transformação das variáveis para melhorar a performance do modelo.
# ##### 3. Análise de Recursos: Seleção e engenharia de características que melhor expliquem a variabilidade nos preços das casas.
# ##### 4. Treinamento e Avaliação de Modelos: Construção de diferentes modelos de aprendizado de máquina
# ##### 5. Interpretação dos Resultados: Análise dos fatores que mais influenciam os preços, com o objetivo de gerar insights valiosos para o mercado imobiliário.
#
# ##### A conclusão do projeto mostrará a eficiência do modelo em prever os preços, destacando os passos importantes para alcançar uma solução robusta e que possa ser aplicada a cenários do mundo real. Este notebook integra técnicas avançadas de ciência de dados, tornando-o uma peça fundamental no portfólio para demonstrar habilidades técnicas e analíticas na resolução de problemas complexos.

# %% [markdown]
#  ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  #### Dicionário de dados
# - <span style="color: #00ced1;">MSSubClass</span>: Identifica o tipo de habitação envolvida na venda.
# - <span style="color: #00ced1;">MSZoning</span>: Classificação geral de zoneamento da venda.
# - <span style="color: #00ced1;">LotFrontage</span>: Comprimento em pés da frente de rua conectada à propriedade.
# - <span style="color: #00ced1;">LotArea</span>: Tamanho do lote em pés quadrados.
# - <span style="color: #00ced1;">Street</span>: Tipo de acesso rodoviário à propriedade.
# - <span style="color: #00ced1;">Alley</span>: Tipo de acesso a beco na propriedade.
# - <span style="color: #00ced1;">LotShape</span>: Formato geral da propriedade.
# - <span style="color: #00ced1;">LandContour</span>: Nivelamento da propriedade.
# - <span style="color: #00ced1;">Utilities</span>: Tipo de utilidades disponíveis.
# - <span style="color: #00ced1;">LotConfig</span>: Configuração do lote.
# - <span style="color: #00ced1;">LandSlope</span>: Inclinação do terreno.
# - <span style="color: #00ced1;">Neighborhood</span>: Localização física dentro dos limites da cidade de Ames.
# - <span style="color: #00ced1;">Condition1</span>: Proximidade a várias condições.
# - <span style="color: #00ced1;">Condition2</span>: Proximidade a várias condições (se houver mais de uma).
# - <span style="color: #00ced1;">BldgType</span>: Tipo de moradia.
# - <span style="color: #00ced1;">HouseStyle</span>: Estilo de moradia.
# - <span style="color: #00ced1;">OverallQual</span>: Avaliação geral de material e acabamento.
# - <span style="color: #00ced1;">OverallCond</span>: Avaliação geral da condição.
# - <span style="color: #00ced1;">YearBuilt</span>: Ano em que a casa foi construída.
# - <span style="color: #00ced1;">YearRemodAdd</span>: Ano em que a casa foi reformada.
# - <span style="color: #00ced1;">RoofStyle</span>: Tipo de telhado.
# - <span style="color: #00ced1;">RoofMatl</span>: Material do telhado.
# - <span style="color: #00ced1;">Exterior1st</span>: Material de revestimento exterior.
# - <span style="color: #00ced1;">Exterior2nd</span>: Material de revestimento exterior (se houver mais de um).
# - <span style="color: #00ced1;">MasVnrType</span>: Tipo de revestimento de alvenaria.
# - <span style="color: #00ced1;">MasVnrArea</span>: Área de revestimento de alvenaria em pés quadrados.
# - <span style="color: #00ced1;">ExterQual</span>: Qualidade do material exterior.
# - <span style="color: #00ced1;">ExterCond</span>: Condição do material exterior.
# - <span style="color: #00ced1;">Foundation</span>: Tipo de fundação.
# - <span style="color: #00ced1;">BsmtQual</span>: Altura do porão.
# - <span style="color: #00ced1;">BsmtCond</span>: Condição geral do porão.
# - <span style="color: #00ced1;">BsmtExposure</span>: Abertura do porão (janelas).
# - <span style="color: #00ced1;">BsmtFinType1</span>: Qualidade da área terminada do porão.
# - <span style="color: #00ced1;">BsmtFinSF1</span>: Área terminada do porão em pés quadrados.
# - <span style="color: #00ced1;">BsmtFinType2</span>: Tipo de acabamento secundário do porão.
# - <span style="color: #00ced1;">BsmtFinSF2</span>: Área secundária terminada do porão em pés quadrados.
# - <span style="color: #00ced1;">BsmtUnfSF</span>: Área não terminada do porão em pés quadrados.
# - <span style="color: #00ced1;">TotalBsmtSF</span>: Área total do porão em pés quadrados.
# - <span style="color: #00ced1;">Heating</span>: Tipo de sistema de aquecimento.
# - <span style="color: #00ced1;">HeatingQC</span>: Qualidade e condição do aquecimento.
# - <span style="color: #00ced1;">CentralAir</span>: Presença de ar condicionado central.
# - <span style="color: #00ced1;">Electrical</span>: Sistema elétrico.
# - <span style="color: #00ced1;">1stFlrSF</span>: Área do primeiro andar em pés quadrados.
# - <span style="color: #00ced1;">2ndFlrSF</span>: Área do segundo andar em pés quadrados.
# - <span style="color: #00ced1;">LowQualFinSF</span>: Área acabada de baixa qualidade em pés quadrados.
# - <span style="color: #00ced1;">GrLivArea</span>: Área acima do solo em pés quadrados.
# - <span style="color: #00ced1;">BsmtFullBath</span>: Banheiros completos no porão.
# - <span style="color: #00ced1;">BsmtHalfBath</span>: Banheiros meio no porão.
# - <span style="color: #00ced1;">FullBath</span>: Banheiros completos acima do solo.
# - <span style="color: #00ced1;">HalfBath</span>: Banheiros meio acima do solo.
# - <span style="color: #00ced1;">BedroomAbvGr</span>: Número de quartos acima do solo.
# - <span style="color: #00ced1;">KitchenAbvGr</span>: Número de cozinhas acima do solo.
# - <span style="color: #00ced1;">KitchenQual</span>: Qualidade da cozinha.
# - <span style="color: #00ced1;">TotRmsAbvGrd</span>: Total de quartos acima do solo.
# - <span style="color: #00ced1;">Functional</span>: Classificação de funcionalidade do lar.
# - <span style="color: #00ced1;">Fireplaces</span>: Número de lareiras.
# - <span style="color: #00ced1;">GarageType</span>: Localização da garagem.
# - <span style="color: #00ced1;">GarageYrBlt</span>: Ano de construção da garagem.
# - <span style="color: #00ced1;">GarageFinish</span>: Acabamento interior da garagem.
# - <span style="color: #00ced1;">GarageCars</span>: Capacidade de veículos na garagem.
# - <span style="color: #00ced1;">GarageArea</span>: Área da garagem em pés quadrados.
# - <span style="color: #00ced1;">GarageQual</span>: Qualidade da garagem.
# - <span style="color: #00ced1;">GarageCond</span>: Condição da garagem.
# - <span style="color: #00ced1;">PavedDrive</span>: Condição da entrada pavimentada.
# - <span style="color: #00ced1;">WoodDeckSF</span>: Área do deck de madeira em pés quadrados.
# - <span style="color: #00ced1;">OpenPorchSF</span>: Área de varanda aberta em pés quadrados.
# - <span style="color: #00ced1;">EnclosedPorch</span>: Área de varanda fechada em pés quadrados.
# - <span style="color: #00ced1;">3SsnPorch</span>: Área de varanda de três estações em pés quadrados.
# - <span style="color: #00ced1;">ScreenPorch</span>: Área de varanda com tela em pés quadrados.
# - <span style="color: #00ced1;">PoolArea</span>: Área da piscina em pés quadrados.
# - <span style="color: #00ced1;">PoolQC</span>: Qualidade da piscina.
# - <span style="color: #00ced1;">Fence</span>: Qualidade da cerca.
# - <span style="color: #00ced1;">MiscFeature</span>: Características diversas não incluídas em outras categorias.
# - <span style="color: #00ced1;">MiscVal</span>: Valor das características diversas.
# - <span style="color: #00ced1;">MoSold</span>: Mês em que a venda ocorreu.
# - <span style="color: #00ced1;">YrSold</span>: Ano em que a venda ocorreu.
# - <span style="color: #00ced1;">SaleType</span>: Tipo de venda.
# - <span style="color: #00ced1;">SaleCondition</span>: Condição de venda.

# %% [markdown]
# ##### 1. Import das bibliotecas necessárias para o projeto

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
import sklearn.linear_model as linear_model
import seaborn as sns
import xgboost as xgb
import joblib
from scipy.stats import skew, kurtosis, boxcox
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
import optuna
import warnings
import mlflow
import mlflow.sklearn
from mlflow import log_metric, log_param
import subprocess
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### 1.1 Lendo o dataset de Treinamento

# %%
train = pd.read_csv(r'C:\Users\bruno\OneDrive\Desktop\Modelos\Regressão\House_Prices\train.csv') #Dataset de Treino

# %% [markdown]
# ##### Mantendo a integridade do dataset de Treinamento

# %%
df_train = train.copy()

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ##### 1.2 Remoção da coluna Id do dataset de Treinamento

# %%
df_train.drop(columns=['Id'],inplace=True)
df_train.reset_index(drop=True)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# ##### 2. Realizando o Data Splitting antes de começar a análise para evitar o Data Leakage
#
# ###### Data leakage (vazamento de dados) é um problema em aprendizado de máquina que ocorre quando informações do conjunto de dados de teste ou de validação são indevidamente utilizadas durante o treinamento do modelo. Isso leva o modelo a aprender padrões que não estarão disponíveis em dados reais, resultando em avaliações de desempenho superestimadas e um modelo com baixa capacidade de generalização.

# %%
# Separar a variável target (SalePrice) das features
X = df_train.drop(columns=['SalePrice']) # Features (independentes)
y = df_train['SalePrice']                 # Target (dependente)

# Dividir o dataset em treino e teste (75% treino, 25% teste)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# Converter as saídas do split para pandas DataFrame ou Series, conforme necessário
X_train = pd.DataFrame(X_train, columns=X.columns)
X_test = pd.DataFrame(X_test, columns=X.columns)
y_train = pd.Series(y_train, name='SalePrice')
y_test = pd.Series(y_test, name='SalePrice')

# Resetar os índices após o split
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# Verificar as dimensões após o reset de índices
print("Dimensões do conjunto de treino:")
print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print("\nDimensões do conjunto de teste:")
print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Dimensões do conjunto de treino:
# X_train: (1095, 79), y_train: (1095,)
#
# Dimensões do conjunto de teste:
# X_test: (365, 79), y_test: (365,)

# %% [markdown]
# ##### 2.1 Preparação dos Dados

# %%
X_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0         120       RL         43.0     3182   Pave   NaN      Reg
# 1          20       RL         78.0    10140   Pave   NaN      Reg
# 2          50       RL         60.0     9060   Pave   NaN      Reg
# 3          20       RL          NaN    12342   Pave   NaN      IR1
# 4          20       RL         75.0     9750   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1         Lvl    AllPub    Inside  ...           0      648     Fa  GdPrv
# 2         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 3         Lvl    AllPub    Inside  ...           0        0    NaN   GdWo
# 4         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1095 non-null   int64
#  1   MSZoning       1095 non-null   object
#  2   LotFrontage    895 non-null    float64
#  3   LotArea        1095 non-null   int64
#  4   Street         1095 non-null   object
#  5   Alley          70 non-null     object
#  6   LotShape       1095 non-null   object
#  7   LandContour    1095 non-null   object
#  8   Utilities      1095 non-null   object
#  9   LotConfig      1095 non-null   object
#  10  LandSlope      1095 non-null   object
#  11  Neighborhood   1095 non-null   object
#  12  Condition1     1095 non-null   object
#  13  Condition2     1095 non-null   object
#  14  BldgType       1095 non-null   object
#  15  HouseStyle     1095 non-null   object
#  16  OverallQual    1095 non-null   int64
# ...

# %% [markdown]
# ##### 2.2 Análise Exploratória dos Dados (EDA)
# ###### Conjunto de métodos que permite analisar e investigar um conjunto de dados, de forma a compreender o comportamento das variáveis e a relação entre elas.

# %%
X_train_numericas = X_train.select_dtypes(include=[np.number])
X_train_categoricas = X_train.select_dtypes(include=['object','category'])

# %% [markdown]
# ##### 2.3 Análise de Dados Faltantes
# ###### A análise de dados ausentes é fundamental no pré-processamento para modelagem, pois garante a qualidade, precisão e robustez do modelo. Essa etapa permite identificar padrões de ausência, entender o mecanismo de ocorrência (MCAR, MAR ou MNAR) e selecionar estratégias adequadas, como imputação ou exclusão. O tratamento correto minimiza viés, preserva a integridade do dataset, reduz perdas de informação e melhora a capacidade de generalização do modelo, evitando erros e incertezas. Além disso, a análise orienta na escolha de algoritmos apropriados para lidar com dados ausentes, otimizando o desempenho preditivo.

# %% [markdown]
# ##### Análise das Variáveis Numéricas

# %%
# Contar valores ausentes por coluna categórica
missing_numeric = X_train_numericas.isna().sum()

# Filtrar apenas as colunas com valores ausentes
missing_numeric = missing_numeric[missing_numeric > 0]

# Calcular o percentual de valores ausentes
percentual_missing = (missing_numeric / len(X_train_numericas)) * 100

# Combinar os dados em um DataFrame para facilitar a visualização
missing_summary = pd.DataFrame({
    'Valores Ausentes': missing_numeric,
    'Percentual (%)': percentual_missing
})

print(missing_summary)
# Out:
#              Valores Ausentes  Percentual (%)
# LotFrontage               200       18.264840
# MasVnrArea                  4        0.365297
# GarageYrBlt                58        5.296804

# %%
variables = ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# Estatísticas descritivas
X_train_numericas[variables].describe()
# Out:
#        LotFrontage   MasVnrArea  GarageYrBlt
# count   895.000000  1091.000000  1037.000000
# mean     70.394413   103.368469  1978.694311
# std      25.219301   171.644715    24.810675
# min      21.000000     0.000000  1900.000000
# 25%      59.000000     0.000000  1961.000000
# 50%      70.000000     0.000000  1980.000000
# 75%      80.000000   166.000000  2002.000000
# max     313.000000  1378.000000  2010.000000

# %%
# Histograma para cada variável
for var in variables:
    plt.figure(figsize=(6, 4))
    sns.histplot(X_train_numericas[var], kde=True, bins=30)
    plt.title(f'Distribuição de {var}')
    plt.xlabel(var)
    plt.ylabel('Frequência')
    plt.show()

# %% [markdown]
# ##### Tratamento dos dados faltantes numéricos

# %%
#Cálculo da mediana no X_train e substituição no X_test
X_train_numericas['LotFrontage'].fillna(X_train_numericas['LotFrontage'].median(), inplace=True)
X_test['LotFrontage'].fillna(X_train_numericas['LotFrontage'].median(), inplace=True)

#Substituição por zero no X_train e X_test
X_train_numericas['MasVnrArea'].fillna(0, inplace=True)
X_test['MasVnrArea'].fillna(0, inplace=True)

#Substituição por Year Built no X_train e X_test
X_train_numericas['GarageYrBlt'].fillna(X_train_numericas['YearBuilt'], inplace=True)
X_test['GarageYrBlt'].fillna(X_test['YearBuilt'], inplace=True)

# %%
X_train_numericas.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            20       RL         70.0     8414   Pave   NaN      Reg
# 1            60       RL         98.0    12256   Pave   NaN      IR1
# 2            30       RM         56.0     8960   Pave  Grvl      Reg
# 3            50       RM         50.0     5000   Pave   NaN      Reg
# 4            20       RL         89.0    12898   Pave   NaN      IR1
# ..          ...      ...          ...      ...    ...   ...      ...
# 360          60       RL         70.0    12046   Pave   NaN      IR1
# 361         160       RL         75.0    10762   Pave   NaN      Reg
# 362          60       RL         70.0     9375   Pave   NaN      Reg
# 363          60       RL         70.0    29959   Pave   NaN      IR2
# 364          20       RL         71.0     9204   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %% [markdown]
# ##### Validação do tratamento das variáveis numéricas

# %%
missing_num = X_train_numericas.isna().sum()
missing_num = missing_num[missing_num > 0]
print(missing_num)
# Out:
# Series([], dtype: int64)

# %%
X_test_numericas = X_test.select_dtypes(include=[np.number])
missing_num = X_test_numericas.isna().sum()
missing_num = missing_num[missing_num > 0]
print(missing_num)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ##### Análise das variáveis categóricas

# %%
# Contar valores ausentes por coluna categórica
missing_categ = X_train_categoricas.isna().sum()

# Filtrar apenas as colunas com valores ausentes
missing_categ = missing_categ[missing_categ > 0]

# Calcular o percentual de valores ausentes
percentual_missing = (missing_categ / len(X_train_categoricas)) * 100

# Combinar os dados em um DataFrame para facilitar a visualização
missing_summary = pd.DataFrame({
    'Valores Ausentes': missing_categ,
    'Percentual (%)': percentual_missing
})

print(missing_summary)
# Out:
#               Valores Ausentes  Percentual (%)
# Alley                     1025       93.607306
# MasVnrType                 639       58.356164
# BsmtQual                    27        2.465753
# BsmtCond                    27        2.465753
# BsmtExposure                27        2.465753
# BsmtFinType1                27        2.465753
# BsmtFinType2                27        2.465753
# Electrical                   1        0.091324
# FireplaceQu                512       46.757991
# GarageType                  58        5.296804
# GarageFinish                58        5.296804
# GarageQual                  58        5.296804
# GarageCond                  58        5.296804
# PoolQC                    1089       99.452055
# Fence                      877       80.091324
# MiscFeature               1052       96.073059

# %% [markdown]
# ##### As variáveis com muitos dados faltantes como PoolQC, MiscFeature, Fence, MasVnrType e FireplaceQu serão excluídas do dataset.

# %%
X_train_categoricas.drop(columns = ['Alley','MasVnrType','FireplaceQu','PoolQC','Fence','MiscFeature'],inplace=True)
X_test.drop(columns = ['Alley','MasVnrType','FireplaceQu','PoolQC','Fence','MiscFeature'],inplace=True)

# %%
X_train_categoricas.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0            20       RL         70.0     8414   Pave      Reg         Lvl
# 1            60       RL         98.0    12256   Pave      IR1         Lvl
# 2            30       RM         56.0     8960   Pave      Reg         Lvl
# 3            50       RM         50.0     5000   Pave      Reg         Lvl
# 4            20       RL         89.0    12898   Pave      IR1         HLS
# ..          ...      ...          ...      ...    ...      ...         ...
# 360          60       RL         70.0    12046   Pave      IR1         Lvl
# 361         160       RL         75.0    10762   Pave      Reg         Lvl
# 362          60       RL         70.0     9375   Pave      Reg         Lvl
# 363          60       RL         70.0    29959   Pave      IR2         Lvl
# 364          20       RL         71.0     9204   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# ##### Distribuição das variáveis categóricas com dados missing
#
# ###### Substituição dos dados faltantes pela palavra Missing, apenas para análise gráfica.

# %%
cols = ['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','GarageType','GarageFinish','GarageQual','GarageCond']

X_train_categoricas[cols] = X_train_categoricas[cols].fillna('Missing')

# Gráficos de barras para cada variável categórica
for col in cols:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=X_train_categoricas, x=col, order=X_train_categoricas[col].value_counts().index, palette='viridis')
    plt.title(f'Distribuição da variável {col}')
    plt.xlabel(col)
    plt.ylabel('Frequência')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Substituir valores missing pela moda de cada coluna
for col in cols:
    moda = X_train_categoricas[col].mode()[0]  # Calcula a moda (valor mais frequente)
    X_train_categoricas[col].fillna(moda, inplace=True) # Substitui valores missing pela moda
    X_test[col].fillna(moda,inplace=True) # Substitui valores missing pela moda no X_test

# Verificar se os valores missing foram preenchidos
print(X_train_categoricas[cols].isnull().sum())
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %% [markdown]
# ##### Validação das substituições

# %%
X_train_numericas.reset_index(drop=True,inplace=True)
X_train_categoricas.reset_index(drop=True,inplace=True)
X_test.reset_index(drop=True)

X_train = pd.concat([X_train_numericas,X_train_categoricas],axis=1)

# %%
X_train.shape
# Out:
# (1095, 73)

# %%
X_test.shape
# Out:
# (365, 73)

# %%
missing = X_train.isna().sum()

missing = missing[missing > 0]

missing
# Out:
# Series([], dtype: int64)

# %%
missing = X_test.isna().sum()

missing = missing[missing > 0]

missing
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ##### 2.4 Outliers

# %%
# Selecionar as variáveis numéricas, excluindo SalePrice
numerical_columns = X_train.select_dtypes(include=['float64', 'int64']).columns
numerical_columns = [col for col in numerical_columns if col != 'SalePrice']  # Excluir SalePrice

# Definir o número de subplots
n_cols = 3  # Defina o número de colunas de subplots
n_rows = len(numerical_columns) // n_cols + (len(numerical_columns) % n_cols > 0)  # Número de linhas

# Criar os subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

# Ajustar o layout para não sobrepor os gráficos
fig.tight_layout(pad=5.0)

# Plotar um boxplot para cada variável numérica
for i, col in enumerate(numerical_columns):
    ax = axes[i // n_cols, i % n_cols]  # Definir o eixo correto para o subplot
    sns.boxplot(x = X_train[col], ax=ax)
    ax.set_title(f'Boxplot - {col}')
    ax.set_xlabel(col)

# Remover subplots não utilizados, se houver
for j in range(i + 1, n_rows * n_cols):
    fig.delaxes(axes.flatten()[j])
plt.show()

# %% [markdown]
# ##### Identificação dos Outliers por meio do método IQR (Intervalo Interquartil)
#
# ###### O IQR (Interquartile Range), ou intervalo interquartil, é uma medida estatística de dispersão que representa a diferença entre o terceiro quartil (Q3, ou 75º percentil) e o primeiro quartil (Q1, ou 25º percentil) de um conjunto de dados.
# ###### O multiplicador 1.5 no cálculo do IQR é usado para identificar outliers ao estabelecer limites além dos quais os dados são considerados extremos. Ele define uma faixa que cobre a maioria dos dados legítimos, mesmo em distribuições assimétricas, é uma escolha empírica e equilibrada.

# %%
# Selecionar variáveis numéricas, excluindo 'SalePrice'
numerical_columns = X_train.select_dtypes(include=['float64', 'int64']).columns.tolist()
numerical_columns = [col for col in numerical_columns if col != 'SalePrice']

# Função para substituir os outliers pelo limite calculado com IQR
def replace_outliers_with_limits_IQR(df, col, lower_limit, upper_limit):
    df[col] = np.where(df[col] < lower_limit, lower_limit, df[col])
    df[col] = np.where(df[col] > upper_limit, upper_limit, df[col])
    return df

# Calcular os limites IQR para X_train
outlier_limits = {}
for col in numerical_columns:
    Q1 = X_train[col].quantile(0.25)
    Q3 = X_train[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    # Armazenar limites
    outlier_limits[col] = (lower_limit, upper_limit)

# Aplicar os limites ao X_train e X_test
for col in numerical_columns:
    lower_limit, upper_limit = outlier_limits[col]
    X_train = replace_outliers_with_limits_IQR(X_train, col, lower_limit, upper_limit)
    X_test = replace_outliers_with_limits_IQR(X_test, col, lower_limit, upper_limit)
# Mostrar as primeiras linhas após o tratamento
print(X_train.head())
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       120.0         43.0   3182.0          7.0          5.0     2005.0
# 1        20.0         78.0  10140.0          6.0          6.0     1974.0
# 2        50.0         60.0   9060.0          6.0          5.0     1939.0
# 3        20.0         70.0  12342.0          5.0          5.0     1960.0
# 4        20.0         75.0   9750.0          6.0          6.0     1958.0
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  Electrical  \
# 0        2006.0        14.0        16.0         0.0  ...       SBrkr
# 1        1999.0        99.0       663.0         0.0  ...       SBrkr
# 2        1950.0         0.0       204.0         0.0  ...       SBrkr
# 3        1978.0         0.0         0.0         0.0  ...       SBrkr
# 4        1958.0       243.0       608.0         0.0  ...       SBrkr
#
#    KitchenQual  Functional  GarageType  GarageFinish  GarageQual  GarageCond  \
# ...

# %% [markdown]
# ##### Caso os valores ultrapassem os limites definidos, a substituição do valor pelo limite inferior ou superior correspondente é realizada.

# %%
X_train.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20.0       RL         70.0   8414.0   Pave      Reg         Lvl
# 1          60.0       RL         98.0  12256.0   Pave      IR1         Lvl
# 2          30.0       RM         56.0   8960.0   Pave      Reg         Lvl
# 3          50.0       RM         50.0   5000.0   Pave      Reg         Lvl
# 4          20.0       RL         89.0  12898.0   Pave      IR1         HLS
# ..          ...      ...          ...      ...    ...      ...         ...
# 360        60.0       RL         70.0  12046.0   Pave      IR1         Lvl
# 361       145.0       RL         75.0  10762.0   Pave      Reg         Lvl
# 362        60.0       RL         70.0   9375.0   Pave      Reg         Lvl
# 363        60.0       RL         70.0  17866.5   Pave      IR2         Lvl
# 364        20.0       RL         71.0   9204.0   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# ##### Validação do tratamento dos Outliers

# %%
# Definir o número de subplots
n_cols = 3  # Defina o número de colunas de subplots
n_rows = len(numerical_columns) // n_cols + (len(numerical_columns) % n_cols > 0)  # Número de linhas

# Criar os subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

# Ajustar o layout para não sobrepor os gráficos
fig.tight_layout(pad=5.0)

# Plotar um boxplot para cada variável numérica
for i, col in enumerate(numerical_columns):
    ax = axes[i // n_cols, i % n_cols]  # Definir o eixo correto para o subplot
    sns.boxplot(x=X_train[col], ax=ax)
    ax.set_title(f'Boxplot - {col}')
    ax.set_xlabel(col)

# Remover subplots não utilizados, se houver
for j in range(i + 1, n_rows * n_cols):
    fig.delaxes(axes.flatten()[j])

plt.show()

# %% [markdown]
# ##### Após o tratamento dos Outliers, algumas variáveis carregam valores únicos, e não são interessantes para o conjunto de treinamento, por isso serão excluídas.

# %%
X_train.drop(columns=['MiscVal','PoolArea','ScreenPorch','3SsnPorch','EnclosedPorch','KitchenAbvGr','BsmtHalfBath','LowQualFinSF','BsmtFinSF2'],inplace=True)
X_test.drop(columns=['MiscVal','PoolArea','ScreenPorch','3SsnPorch','EnclosedPorch','KitchenAbvGr','BsmtHalfBath','LowQualFinSF','BsmtFinSF2'],inplace=True)

# %%
X_train.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          20.0       RL         70.0   8414.0   Pave      Reg         Lvl
# 1          60.0       RL         98.0  12256.0   Pave      IR1         Lvl
# 2          30.0       RM         56.0   8960.0   Pave      Reg         Lvl
# 3          50.0       RM         50.0   5000.0   Pave      Reg         Lvl
# 4          20.0       RL         89.0  12898.0   Pave      IR1         HLS
# ..          ...      ...          ...      ...    ...      ...         ...
# 360        60.0       RL         70.0  12046.0   Pave      IR1         Lvl
# 361       145.0       RL         75.0  10762.0   Pave      Reg         Lvl
# 362        60.0       RL         70.0   9375.0   Pave      Reg         Lvl
# 363        60.0       RL         70.0  17866.5   Pave      IR2         Lvl
# 364        20.0       RL         71.0   9204.0   Pave      Reg         Lvl
#
# ...

# %%
X_train.shape
# Out:
# (1095, 64)

# %%
X_test.shape
# Out:
# (365, 64)

# %% [markdown]
# ##### 2.5 Variável Target - SalePrice

# %%
# Histograma com KDE
sns.histplot(y_train, kde=True, bins=30)
plt.title('Distribuição da variável SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Frequência')
plt.show()

# Skewness e Kurtosis
skewness = skew(y_train)
kurt = kurtosis(y_train)
print(f'Assimetria: {skewness:.2f}')
print(f'Curtose: {kurt:.2f}')
# Out:
# Assimetria: 1.75
# Curtose: 5.53

# %% [markdown]
# ###### A assimetria mede o grau de assimetria (ou falta de simetria) de uma distribuição de dados em torno de sua média. Ela indica se a distribuição está inclinada para a direita (assimetria positiva) ou para a esquerda (assimetria negativa).
# ###### A curtose mede a "altura" das caudas de uma distribuição, ou seja, a quantidade de dados concentrados nas extremidades (caudas) da distribuição, em comparação com uma distribuição normal.

# %% [markdown]
# ##### Aplicação da transformação **BoxCox**
#
# ###### A transformação Box-Cox é uma técnica estatística utilizada para estabilizar a variância e tornar os dados mais próximos de uma distribuição normal. É particularmente útil quando os dados apresentam assimetrias ou heterocedasticidade (variação não constante dos erros).

# %%
# Aplicando Box-Cox no y_train e armazenando o lambda utilizado
y_train, fitted_lambda = boxcox(y_train)

# Aplicando Box-Cox no y_test com o lambda calculado no y_train
y_test = boxcox(y_test, lmbda=fitted_lambda)

# Verificar as transformações
print("y_train transformado:", y_train[:5])
print("y_test transformado:", y_test[:5])
# Out:
# y_train transformado: [7.894539   7.87341571 7.65452121 7.77102098 7.81939021]
# y_test transformado: [7.81072428 8.09869235 7.691732   7.82215092 8.08751719]

# %%
# Plotar o histograma da variável transformada
sns.histplot(y_train, kde=True, bins=30)
plt.title('Distribuição de SalePrice (Box-Cox)')
plt.xlabel('SalePrice (Box-Cox)')
plt.ylabel('Frequência')
plt.show()

# Verificar a assimetria
new_skewness = skew(y_train)
print(f'Assimetria após Box-Cox: {new_skewness:.2f}')
# Out:
# Assimetria após Box-Cox: -0.01

# %% [markdown]
# ##### Análise da Distribuição das demais variáveis númericas

# %%
# Selecionar as variáveis numéricas, excluindo 'SalePrice'
numerical_columns = X_train.select_dtypes(include=['float64', 'int64']).columns.tolist()  # Seleciona as colunas numéricas
numerical_columns = [col for col in numerical_columns if col != 'SalePrice']

# Definir o número de colunas para o grid de gráficos
n_cols = 4  # Ajuste conforme o número de variáveis
n_rows = -(-len(numerical_columns) // n_cols)  # Calcular o número de linhas necessárias

# Criar a figura
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 4))

# Garantir que seja uma matriz de eixos (para datasets pequenos)
axes = axes.ravel() if n_rows > 1 else [axes]

# Plotar cada variável
for i, col in enumerate(numerical_columns):
    sns.histplot(X_train[col], kde=True, ax=axes[i], bins=30)
    axes[i].set_title(f'Distribuição de {col}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Frequência')

# Remover eixos extras (se houver)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Análise da Assimetria das variáveis numéricas

# %%
skewness = X_train[numerical_columns].apply(skew)
print(skewness)
# Out:
# MSSubClass      1.017000
# LotFrontage     0.061268
# LotArea         0.208234
# OverallQual     0.203558
# OverallCond     0.585441
# YearBuilt      -0.606035
# YearRemodAdd   -0.504250
# MasVnrArea      1.270470
# BsmtFinSF1      0.713952
# BsmtUnfSF       0.806071
# TotalBsmtSF     0.216745
# 1stFlrSF        0.596323
# 2ndFlrSF        0.784047
# GrLivArea       0.577395
# BsmtFullBath    0.571577
# FullBath        0.073927
# HalfBath        0.624600
# BedroomAbvGr   -0.245600
# TotRmsAbvGrd    0.355959
# Fireplaces      0.564643
# GarageYrBlt    -0.673728
# GarageCars     -0.444507
# GarageArea     -0.093693
# WoodDeckSF      1.090291
# OpenPorchSF     1.155410
# MoSold          0.244789
# YrSold          0.086307
# dtype: float64

# %% [markdown]
# ##### Aplicar a transformação BoxCox para variáveis com assimetria maior do que 1 e, caso a variável tenha valores negativos, aplicaremos a transformação Yeo-Johnson.

# %%
# Calcular a assimetria das variáveis numéricas em X_train
numerical_columns = X_train.select_dtypes(include=['float64', 'int64']).columns
skewness = X_train[numerical_columns].apply(skew)

# Filtrar variáveis com alta assimetria (|skew| > 1)
high_skew = skewness[abs(skewness) > 1].index
print(f'Variáveis com alta assimetria:\n{high_skew}')
# Out:
# Variáveis com alta assimetria:
# Index(['MSSubClass', 'MasVnrArea', 'WoodDeckSF', 'OpenPorchSF'], dtype='object')

# %%
# Variáveis de interesse
variables_of_interest = ['MSSubClass', 'MasVnrArea', 'WoodDeckSF', 'OpenPorchSF']

# Criar o PowerTransformer para Yeo-Johnson
pt = PowerTransformer(method='yeo-johnson')

# Dicionário para armazenar os lambdas de Box-Cox
boxcox_lambdas = {}

# Dicionário para armazenar os objetos PowerTransformer para cada variável
power_transformers = {}

# Processar as variáveis de interesse
for col in variables_of_interest:
    # Verificar se a variável tem apenas valores positivos em X_train
    if (X_train[col] > 0).all():  # Para Box-Cox, todos os valores devem ser positivos
        # Aplicar Box-Cox em X_train
        X_train[col], lambda_ = boxcox(X_train[col])
        boxcox_lambdas[col] = lambda_
        print(f'Box-Cox aplicado na variável {col} no X_train com lambda: {lambda_}')
        
        # Aplicar a mesma transformação em X_test utilizando o lambda salvo
        X_test[col] = boxcox(X_test[col], lmbda=lambda_)
        print(f'Box-Cox aplicado na variável {col} no X_test com lambda: {lambda_}')
        
    else:
        # Aplicar Yeo-Johnson em X_train e salvar o PowerTransformer
        pt_fitted = pt.fit(X_train[[col]])  # Ajustar PowerTransformer em X_train
        power_transformers[col] = pt_fitted  # Armazenar o objeto PowerTransformer
        X_train[col] = pt_fitted.transform(X_train[[col]])  # Transformar X_train
        print(f'Yeo-Johnson aplicado na variável {col} no X_train')

        # Aplicar a mesma transformação em X_test com o PowerTransformer ajustado
        X_test[col] = pt_fitted.transform(X_test[[col]])  # Transformar X_test
        print(f'Yeo-Johnson aplicado na variável {col} no X_test')
# Out:
# Box-Cox aplicado na variável MSSubClass no X_train com lambda: -0.12268687316042722
# Box-Cox aplicado na variável MSSubClass no X_test com lambda: -0.12268687316042722
# Yeo-Johnson aplicado na variável MasVnrArea no X_train
# Yeo-Johnson aplicado na variável MasVnrArea no X_test
# Yeo-Johnson aplicado na variável WoodDeckSF no X_train
# Yeo-Johnson aplicado na variável WoodDeckSF no X_test
# Yeo-Johnson aplicado na variável OpenPorchSF no X_train
# Yeo-Johnson aplicado na variável OpenPorchSF no X_test

# %%
X_train.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0      2.506889       RL         70.0   8414.0   Pave      Reg         Lvl
# 1      3.218570       RL         98.0  12256.0   Pave      IR1         Lvl
# 2      2.780779       RM         56.0   8960.0   Pave      Reg         Lvl
# 3      3.107000       RM         50.0   5000.0   Pave      Reg         Lvl
# 4      2.506889       RL         89.0  12898.0   Pave      IR1         HLS
# ..          ...      ...          ...      ...    ...      ...         ...
# 360    3.218570       RL         70.0  12046.0   Pave      IR1         Lvl
# 361    3.724638       RL         75.0  10762.0   Pave      Reg         Lvl
# 362    3.218570       RL         70.0   9375.0   Pave      Reg         Lvl
# 363    3.218570       RL         70.0  17866.5   Pave      IR2         Lvl
# 364    2.506889       RL         71.0   9204.0   Pave      Reg         Lvl
#
# ...

# %%
X_train.shape
# Out:
# (1095, 64)

# %%
X_test.shape
# Out:
# (365, 64)

# %%
new_skewness = X_train[high_skew].apply(skew)
print(f'Nova assimetria após transformação:\n{new_skewness}')
# Out:
# Nova assimetria após transformação:
# MSSubClass     0.038909
# MasVnrArea     0.370883
# WoodDeckSF     0.154632
# OpenPorchSF   -0.059997
# dtype: float64

# %% [markdown]
# ##### 3. Correlação de Pearson
#
# ###### A Correlação de Pearson é uma medida estatística que avalia a força e a direção da relação linear entre duas variáveis numéricas. O valor da correlação de Pearson varia entre -1 e 1, na qual os limites indicam correlação forte (positiva ou negativa).

# %%
# Juntar X_train e y_train (supondo que y_train seja uma série ou DataFrame)
df_train_combined = X_train.copy()  # Copiar X_train para não modificar o original
df_train_combined['SalePrice'] = y_train  # Adicionar y_train ao DataFrame combinado

# Selecionar as variáveis numéricas para análise de correlação
X_train_numericas = df_train_combined.select_dtypes(include=[np.number])

# Calcular a matriz de correlação
corr_matrix = X_train_numericas.corr(method='pearson')

# Exibir a matriz de correlação como um heatmap
plt.figure(figsize=(30, 15))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Matriz de Correlação entre Variáveis Numéricas")
plt.show()

# %% [markdown]
# ##### Pares de variáveis altamente correlacionados

# %%
# Encontrar pares altamente correlacionados (maior que 0.8 ou menor que -0.8)
high_corr_var = []
threshold = 0.8  # Limite de correlação para considerar alto

for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            high_corr_var.append((corr_matrix.columns[i], corr_matrix.columns[j], corr_matrix.iloc[i, j]))

# Exibir os pares com correlação alta
high_corr_var
# Out:
# [('TotRmsAbvGrd', 'GrLivArea', np.float64(0.8334578916158892)),
#  ('GarageYrBlt', 'YearBuilt', np.float64(0.83731678741266)),
#  ('GarageArea', 'GarageCars', np.float64(0.8900969555924543)),
#  ('SalePrice', 'OverallQual', np.float64(0.8074590679366267))]

# %% [markdown]
# ##### Dropar variáveis altamente correlacionadas, com o objetivo de evitar a multicolinearidade.
#
# ###### A multicolinearidade ocorre quando duas ou mais variáveis independentes em um modelo de regressão estão altamente correlacionadas entre si. Isso significa que elas fornecem informações redundantes ou sobrepostas, dificultando a determinação de seus efeitos individuais sobre a variável dependente.

# %%
df_train_combined.drop(columns=['TotRmsAbvGrd','GarageYrBlt','GarageCars','OverallQual'],inplace=True)
X_test.drop(columns=['TotRmsAbvGrd','GarageYrBlt','GarageCars','OverallQual'],inplace=True)

# %%
df_train_combined.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0      2.506889       RL         70.0   8414.0   Pave      Reg         Lvl
# 1      3.218570       RL         98.0  12256.0   Pave      IR1         Lvl
# 2      2.780779       RM         56.0   8960.0   Pave      Reg         Lvl
# 3      3.107000       RM         50.0   5000.0   Pave      Reg         Lvl
# 4      2.506889       RL         89.0  12898.0   Pave      IR1         HLS
# ..          ...      ...          ...      ...    ...      ...         ...
# 360    3.218570       RL         70.0  12046.0   Pave      IR1         Lvl
# 361    3.724638       RL         75.0  10762.0   Pave      Reg         Lvl
# 362    3.218570       RL         70.0   9375.0   Pave      Reg         Lvl
# 363    3.218570       RL         70.0  17866.5   Pave      IR2         Lvl
# 364    2.506889       RL         71.0   9204.0   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# ##### 3.1 Teste ANOVA para variáveis categóricas
#
# ###### O teste ANOVA (Analysis of Variance) é uma técnica estatística usada para comparar as médias de três ou mais grupos e determinar se há diferenças estatisticamente significativas entre eles. Ele verifica se a variação entre as médias dos grupos é maior do que a variação dentro dos próprios grupos, levando em conta a variância geral.
# ###### As variáveis independentes precisam ser categóricas e a dependente contínua.

# %%
# Selecionar as variáveis categóricas do df_train
categorical_columns = df_train_combined.select_dtypes(include=['object']).columns

# Criar um dicionário para armazenar os resultados
anova_results = {}

# Loop para realizar o teste ANOVA para cada variável categórica
for col in categorical_columns:
    # Agrupar os dados por categoria e obter as distribuições de 'SalePrice'
    grouped = df_train_combined.groupby(col)['SalePrice']
    
    # Aplicar o teste ANOVA
    f_stat, p_value = stats.f_oneway(*[group[1].values for group in grouped])
    
    # Armazenar o p-valor no dicionário de resultados
    anova_results[col] = p_value

# Converter os resultados em DataFrame para visualização
anova_results_df = pd.DataFrame(list(anova_results.items()), columns=['Variable', 'p-value'])

# Exibir as variáveis com p-valor menor que 0.05
significant_vars = anova_results_df[anova_results_df['p-value'] < 0.05]

print("Variáveis com associação significativa com SalePrice:")
print(significant_vars)
# Out:
# Variáveis com associação significativa com SalePrice:
#          Variable        p-value
# 0        MSZoning   1.129561e-40
# 2        LotShape   1.022335e-19
# 3     LandContour   1.319935e-07
# 5       LotConfig   2.686211e-06
# 7    Neighborhood  1.633452e-170
# 8      Condition1   3.100045e-08
# 10       BldgType   2.551089e-10
# 11     HouseStyle   1.617843e-23
# 12      RoofStyle   3.795756e-08
# 14    Exterior1st   1.761857e-42
# 15    Exterior2nd   1.411944e-37
# 16      ExterQual  8.455624e-135
# 17      ExterCond   1.916980e-11
# 18     Foundation   5.145123e-78
# 19       BsmtQual  7.469076e-139
# 20       BsmtCond   1.044454e-23
# 21   BsmtExposure   2.946972e-34
# 22   BsmtFinType1   1.694116e-57
# 23   BsmtFinType2   2.469190e-10
# 24        Heating   2.564115e-07
# 25      HeatingQC   3.091526e-67
# 26     CentralAir   6.563264e-36
# 27     Electrical   7.772875e-21
# 28    KitchenQual  8.583816e-138
# 29     Functional   2.019299e-05
# ...

# %%
# Exibir as variáveis com p-valor maior ou igual a 0.05
non_significant_vars = anova_results_df[anova_results_df['p-value'] >= 0.05]

print("Variáveis sem associação significativa com SalePrice:")
print(non_significant_vars)
# Out:
# Variáveis sem associação significativa com SalePrice:
#       Variable   p-value
# 1       Street  0.658827
# 4    Utilities  0.619478
# 6    LandSlope  0.256547
# 9   Condition2  0.166323
# 13    RoofMatl  0.087250

# %% [markdown]
# ##### Distribuição das variáveis não significativas de acordo com o teste ANOVA

# %%
# Visualizar a distribuição de variáveis não significativas
for col in ['Utilities', 'LandSlope', 'Street','Condition2','RoofMatl']:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df_train_combined, x=col)
    plt.title(f'Distribuição de {col}')
    plt.show()

# %% [markdown]
# ##### Dropar variáveis que não tem associação significativa com o Target SalePrice

# %%
# Remover as variáveis não significativas
df_train_combined.drop(columns=['Utilities', 'LandSlope', 'Street','RoofMatl','Condition2'],inplace=True)
X_test.drop(columns=['Utilities', 'LandSlope', 'Street','RoofMatl','Condition2'],inplace=True)

# Verificar as primeiras linhas após a remoção
df_train_combined.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallCond  YearBuilt  YearRemodAdd  \
# 0    3.620670         43.0   3182.0          5.0     2005.0        2006.0
# 1    2.506889         78.0  10140.0          6.0     1974.0        1999.0
# 2    3.107000         60.0   9060.0          5.0     1939.0        1950.0
# 3    2.506889         70.0  12342.0          5.0     1960.0        1978.0
# 4    2.506889         75.0   9750.0          6.0     1958.0        1958.0
#
#    MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  ...  KitchenQual  \
# 0    0.494705        16.0     1330.0       1346.0  ...           Gd
# 1    1.059388       663.0        0.0       1040.0  ...           Gd
# 2   -0.841898       204.0      356.0        560.0  ...           TA
# 3   -0.841898         0.0      978.0        978.0  ...           TA
# 4    1.254637       608.0      834.0       1442.0  ...           TA
#
#    Functional  GarageType  GarageFinish  GarageQual  GarageCond  PavedDrive  \
# ...

# %%
df_train_combined.reset_index(drop=True)
X_test.reset_index(drop=True)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# 0      2.506889       RL         70.0   8414.0      Reg         Lvl    Inside
# 1      3.218570       RL         98.0  12256.0      IR1         Lvl    Corner
# 2      2.780779       RM         56.0   8960.0      Reg         Lvl    Inside
# 3      3.107000       RM         50.0   5000.0      Reg         Lvl    Corner
# 4      2.506889       RL         89.0  12898.0      IR1         HLS    Inside
# ..          ...      ...          ...      ...      ...         ...       ...
# 360    3.218570       RL         70.0  12046.0      IR1         Lvl    Inside
# 361    3.724638       RL         75.0  10762.0      Reg         Lvl    Corner
# 362    3.218570       RL         70.0   9375.0      Reg         Lvl    Inside
# 363    3.218570       RL         70.0  17866.5      IR2         Lvl       FR2
# 364    2.506889       RL         71.0   9204.0      Reg         Lvl    Inside
#
# ...

# %%
# Separar df_train_combined de volta em X_train e y_train
X_train = df_train_combined.drop(columns=['SalePrice'])  # Remover a coluna 'SalePrice' para X_train
y_train = df_train_combined['SalePrice']  # Atribuir a coluna 'SalePrice' a y_train

# %%
df_train_combined.shape
# Out:
# (1095, 56)

# %%
df_train_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 56 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1095 non-null   float64
#  1   LotFrontage    1095 non-null   float64
#  2   LotArea        1095 non-null   float64
#  3   OverallCond    1095 non-null   float64
#  4   YearBuilt      1095 non-null   float64
#  5   YearRemodAdd   1095 non-null   float64
#  6   MasVnrArea     1095 non-null   float64
#  7   BsmtFinSF1     1095 non-null   float64
#  8   BsmtUnfSF      1095 non-null   float64
#  9   TotalBsmtSF    1095 non-null   float64
#  10  1stFlrSF       1095 non-null   float64
#  11  2ndFlrSF       1095 non-null   float64
#  12  GrLivArea      1095 non-null   float64
#  13  BsmtFullBath   1095 non-null   float64
#  14  FullBath       1095 non-null   float64
#  15  HalfBath       1095 non-null   float64
#  16  BedroomAbvGr   1095 non-null   float64
# ...

# %%
X_test.shape
# Out:
# (365, 55)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 55 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     365 non-null    float64
#  1   MSZoning       365 non-null    object
#  2   LotFrontage    365 non-null    float64
#  3   LotArea        365 non-null    float64
#  4   LotShape       365 non-null    object
#  5   LandContour    365 non-null    object
#  6   LotConfig      365 non-null    object
#  7   Neighborhood   365 non-null    object
#  8   Condition1     365 non-null    object
#  9   BldgType       365 non-null    object
#  10  HouseStyle     365 non-null    object
#  11  OverallCond    365 non-null    float64
#  12  YearBuilt      365 non-null    float64
#  13  YearRemodAdd   365 non-null    float64
#  14  RoofStyle      365 non-null    object
#  15  Exterior1st    365 non-null    object
#  16  Exterior2nd    365 non-null    object
# ...

# %% [markdown]
# ##### 4. One Hot Encoder
# ###### O One-Hot Encoder é uma técnica de pré-processamento usada para converter variáveis categóricas em variáveis numéricas binárias. Ele transforma cada valor único de uma variável categórica em uma nova coluna, onde o valor é representado como 1 (verdadeiro) ou 0 (falso), dependendo da presença ou ausência da categoria.

# %%
# Selecionar as variáveis categóricas
categorical_columns = X_train.select_dtypes(include=['object']).columns

# Criar um pré-processador para aplicar OneHotEncoding nas variáveis categóricas
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore'), categorical_columns)
    ],
    remainder='passthrough'  # Deixar as variáveis numéricas como estão
)

# Aplicando o OneHotEncoder nos dados de treino e teste
X_train_encoded = preprocessor.fit_transform(X_train)
X_test_encoded = preprocessor.transform(X_test)

# Verificar as dimensões após o OneHotEncoder
print("Dimensões de X_train após OneHotEncoder:", X_train_encoded.shape)
print("Dimensões de X_test após OneHotEncoder:", X_test_encoded.shape)
# Out:
# Dimensões de X_train após OneHotEncoder: (1095, 207)
# Dimensões de X_test após OneHotEncoder: (365, 207)

# %% [markdown]
# ##### 4.1 StandardScaler
# ###### O StandardScaler é uma técnica de normalização de dados utilizada para transformar variáveis numéricas para que elas tenham média 0 e desvio padrão 1. Esse processo é conhecido como padronização. A ideia principal é garantir que as variáveis estejam em uma escala semelhante, evitando que variáveis com magnitudes maiores dominem o modelo de aprendizado.

# %%
# Inicializar o StandardScaler
scaler = StandardScaler()

# Aplicando o StandardScaler em X_train_encoded e X_test_encoded
X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

# Verificar as dimensões após a normalização
print("Dimensões de X_train após StandardScaler:", X_train_scaled.shape)
print("Dimensões de X_test após StandardScaler:", X_test_scaled.shape)
# Out:
# Dimensões de X_train após StandardScaler: (1095, 207)
# Dimensões de X_test após StandardScaler: (365, 207)

# %% [markdown]
# ##### 5. Aplicação de Regressão Linear

# %%
mlflow.set_experiment("Regressão Linear com Box-Cox e StandardScaler")

# Inicializar o modelo
linear_model = LinearRegression()

# Iniciar um experimento MLflow
with mlflow.start_run(run_name = "Regressão Linear v1"):
    
    # Registrar hiperparâmetros do modelo
    mlflow.log_param("fit_intercept", linear_model.fit_intercept)
    
    # Treinar o modelo
    linear_model.fit(X_train_scaled, y_train)
    
    # Fazer previsões
    y_pred = linear_model.predict(X_test_scaled)
    
    # Calcular métricas
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    # Registrar métricas no MLflow
    mlflow.log_metric("mean_squared_error", mse)
    mlflow.log_metric("r2_score", r2)
    
    # Registrar o modelo
    mlflow.sklearn.log_model(linear_model, "Regressão Linear")

    print(f"Modelo registrado no MLflow com MSE: {mse:.4f} e R²: {r2:.4f}")
# Out:
# 2024/12/10 21:38:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Modelo registrado no MLflow com MSE: 0.0029 e R²: 0.8917

# %% [markdown]
# ##### 5.1 Aplicação de Regressão Ridge

# %%
mlflow.set_experiment("Regressão Linear Ridge com Box-Cox e StandardScaler")

# Definir os parâmetros do modelo
alpha = 10.0  # Regularização Ridge (quanto maior, mais regularização)

# Iniciar um experimento MLflow
with mlflow.start_run(run_name=" Regressão Ridge V1"):
    
    # Registrar o parâmetro de regularização
    mlflow.log_param("alpha", alpha)

    # Inicializar e treinar o modelo Ridge
    model = Ridge(alpha=alpha)
    model.fit(X_train_scaled, y_train)

    # Fazer previsões
    y_pred = model.predict(X_test_scaled)

    # Calcular as métricas
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)

    # Registrar as métricas
    mlflow.log_metric("mean_squared_error", mse)
    mlflow.log_metric("root_mean_squared_error",rmse)
    mlflow.log_metric("r2_score", r2)

    # Registrar o modelo
    mlflow.sklearn.log_model(model, "Ridge_Model")

    # Exibir as métricas para conferência
    print(f"MSE: {mse:.4f}, RMSE {rmse},  R²: {r2:.4f}")
# Out:
# 2024/12/10 21:38:57 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# MSE: 0.0031, RMSE 0.05590947572576518,  R²: 0.8850

# %% [markdown]
# ##### 5.1 Método K-Fold
# ###### O K-Fold Cross Validation é uma técnica de validação de modelos de aprendizado de máquina. Ela divide o dataset em K subconjuntos (folds), e o modelo é treinado e testado K vezes. A cada iteração, um subconjunto é utilizado como conjunto de teste, enquanto os outros K−1 subconjuntos são usados para treino. O processo é repetido para todos os folds, e o desempenho do modelo é avaliado pela média das métricas obtidas em cada iteração.

# %%
# Definir o modelo
models = {
    'Ridge': Ridge(),
}

# Iniciar um experimento MLflow
mlflow.set_experiment("Regressão Linear Ridge com Box-Cox e StandardScaler e Validação Cruzada (K-Fold)")

with mlflow.start_run(run_name="Regressão Ridge com K-Fold"):
    # Armazenar os resultados
    results = []

    # Definir o número de folds
    kf = KFold(n_splits=10, shuffle=True, random_state=42)  # 10 folds

    # K-Fold Cross Validation
    for name, model in models.items():
        fold_results = {'Model': name, 'R²': [], 'RMSE': [], 'MAE': []}
        
        # Iterar sobre os folds
        for train_index, val_index in kf.split(X_train_scaled):
            # Dividir os dados em treino e validação para cada fold
            X_train_fold, X_val_fold = X_train_encoded[train_index], X_train_encoded[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
            
            # Treinar o modelo
            modelo_ridge_kfold = model.fit(X_train_fold, y_train_fold)
            
            # Fazer previsões
            y_pred = model.predict(X_val_fold)
            
            # Calcular as métricas
            r2 = r2_score(y_val_fold, y_pred)
            rmse = mean_squared_error(y_val_fold, y_pred, squared=False)
            mae = mean_absolute_error(y_val_fold, y_pred)
            
            # Armazenar as métricas para o fold
            fold_results['R²'].append(r2)
            fold_results['RMSE'].append(rmse)
            fold_results['MAE'].append(mae)
            
            # Registrar as métricas no MLFlow
            mlflow.log_metric(f"fold_{len(fold_results['R²'])}_r2", r2)
            mlflow.log_metric(f"fold_{len(fold_results['RMSE'])}_rmse", rmse)
            mlflow.log_metric(f"fold_{len(fold_results['MAE'])}_mae", mae)

        # Calcular as médias das métricas para o modelo
        mean_r2 = np.mean(fold_results['R²'])
        mean_rmse = np.mean(fold_results['RMSE'])
        mean_mae = np.mean(fold_results['MAE'])
        
        # Armazenar os resultados finais para o modelo
        results.append([name, mean_r2, mean_rmse, mean_mae])
        
        # Registrar as médias das métricas no MLflow
        mlflow.log_metric(f"{name}_mean_r2", mean_r2)
        mlflow.log_metric(f"{name}_mean_rmse", mean_rmse)
        mlflow.log_metric(f"{name}_mean_mae", mean_mae)

    # Criar um DataFrame com os resultados
    results_df = pd.DataFrame(results, columns=['Model', 'R²', 'RMSE', 'MAE'])

    # Mostrar os resultados
    print(f"Modelo registrado no MLflow com\n {results_df}")
# Out:
# Modelo registrado no MLflow com
#     Model        R²      RMSE       MAE
# 0  Ridge  0.868555  0.055145  0.036556

# %% [markdown]
# ##### 5.2 Otimização de Hiperparâmetros para a Regressão Ridge (K-Fold)

# %% [markdown]
# ##### GridSearch

# %%
mlflow.set_experiment("Regressão Linear Ridge com Box-Cox, StandardScaler, Validação Cruzada (K-Fold) e Penalização (Alpha = 1)")

with mlflow.start_run(run_name="Regressão Ridge com K-Fold e Grid Search"):
    # Definir o número de folds
    kf = KFold(n_splits=10, shuffle=True, random_state=42)

    # Definir o espaço de hiperparâmetros para o alpha do Ridge
    param_grid = {
        'alpha': np.linspace(0,1,10)  # Explorar uma faixa de valores para o alpha
    }

    # Configurar a busca em grid
    grid_search = GridSearchCV(estimator = modelo_ridge_kfold, param_grid=param_grid, cv = kf, scoring='neg_mean_squared_error', n_jobs=-1)

    # Ajustar o modelo usando o GridSearchCV
    grid_search.fit(X_train_scaled, y_train)

    # Obter os resultados do GridSearch
    grid_results = grid_search.cv_results_

    # Mostrar os melhores parâmetros e resultados
    print(f"Melhor alpha (GridSearch): {grid_search.best_params_['alpha']}")
    print(f"Melhor Score (GridSearch): {grid_search.best_score_}")

    # Calcular as métricas de desempenho no conjunto de dados
    modelo_ridge_melhorado = grid_search.best_estimator_

    r2_grid = r2_score(y_train, modelo_ridge_melhorado.predict(X_train_scaled))
    rmse_grid = mean_squared_error(y_train, modelo_ridge_melhorado.predict(X_train_scaled), squared=False)
    mae_grid = mean_absolute_error(y_train, modelo_ridge_melhorado.predict(X_train_scaled))
    
    mlflow.log_metric(f"{r2_grid}",r2_grid)
    mlflow.log_metric(f"{rmse_grid}",rmse_grid)
    mlflow.log_metric(f"{mae_grid}",mae_grid)

    print(f"GridSearch - R²: {r2_grid}, RMSE: {rmse_grid}, MAE: {mae_grid}")
# Out:
# Melhor alpha (GridSearch): 1.0
# Melhor Score (GridSearch): -0.0034514385235063227
# GridSearch - R²: 0.9298919385989662, RMSE: 0.04119203396191128, MAE: 0.028460165052714297

# %% [markdown]
# ##### **O melhor modelo foi a regressão Ridge com validação cruzada usando K-Fold e otimização de hiperparâmetros utilizando o GridSearch.**

# %% [markdown]
# ##### 6. Salvar Modelo e Scalers para aplicação

# %%
# Salvar o modelo ajustado Ridge
joblib.dump(modelo_ridge_melhorado ,'modelo_regressao_ridge_melhorado.pkl')

# Salvar o scaler para as variáveis numéricas
joblib.dump(scaler, 'standard_scaler.pkl')

# Salvar o preprocessor (OneHotEncoder) utilizado para transformar as variáveis categóricas
joblib.dump(preprocessor, 'OneHotEncoder.pkl')

print("Modelo e scalers salvos com sucesso!")
# Out:
# Modelo e scalers salvos com sucesso!

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### 7. Aplicação do Modelo em **Novos Dados**

# %%
novos_dados = pd.read_csv(r'C:\Users\bruno\OneDrive\Desktop\Modelos\Regressão\House_Prices\test.csv') #Dataset para aplicação de modelo

# %%
id_novos_dados = novos_dados['Id']  # Salva a coluna Id
novos_dados.drop(columns = 'Id',inplace=True)

# %% [markdown]
# ##### Variáveis com Dados Faltantes

# %%
novos_numericas = novos_dados.select_dtypes(include=[np.number])

# Contar valores ausentes por coluna categórica
missing_numeric = novos_numericas.isna().sum()

# Filtrar apenas as colunas com valores ausentes
missing_numeric = missing_numeric[missing_numeric > 0]

# Calcular o percentual de valores ausentes
percentual_missing = (missing_numeric / len(novos_numericas)) * 100

# Combinar os dados em um DataFrame para facilitar a visualização
missing_summary = pd.DataFrame({
    'Valores Ausentes': missing_numeric,
    'Percentual (%)': percentual_missing
})

print(missing_summary)
# Out:
#               Valores Ausentes  Percentual (%)
# LotFrontage                227       15.558602
# MasVnrArea                  15        1.028101
# BsmtFinSF1                   1        0.068540
# BsmtFinSF2                   1        0.068540
# BsmtUnfSF                    1        0.068540
# TotalBsmtSF                  1        0.068540
# BsmtFullBath                 2        0.137080
# BsmtHalfBath                 2        0.137080
# GarageYrBlt                 78        5.346127
# GarageCars                   1        0.068540
# GarageArea                   1        0.068540

# %%
novos_dados['LotFrontage'].fillna(X_train_numericas['LotFrontage'].median(),inplace=True)
novos_dados['MasVnrArea'].fillna(0,inplace=True)
novos_dados['GarageYrBlt'].fillna(novos_dados['YearBuilt'], inplace=True)

# %%
novos_dados.reset_index(drop=True)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             20       RH         80.0    11622   Pave   NaN      Reg
# 1             20       RL         81.0    14267   Pave   NaN      IR1
# 2             60       RL         74.0    13830   Pave   NaN      IR1
# 3             60       RL         78.0     9978   Pave   NaN      IR1
# 4            120       RL         43.0     5005   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
novos_numericas = novos_dados.select_dtypes(include=[np.number])

# Contar valores ausentes por coluna categórica
missing_numeric = novos_numericas.isna().sum()

# Filtrar apenas as colunas com valores ausentes
missing_numeric = missing_numeric[missing_numeric > 0]

# Calcular o percentual de valores ausentes
percentual_missing = (missing_numeric / len(novos_numericas)) * 100

# Combinar os dados em um DataFrame para facilitar a visualização
missing_summary = pd.DataFrame({
    'Valores Ausentes': missing_numeric,
    'Percentual (%)': percentual_missing
})

print(missing_summary)
# Out:
#               Valores Ausentes  Percentual (%)
# BsmtFinSF1                   1         0.06854
# BsmtFinSF2                   1         0.06854
# BsmtUnfSF                    1         0.06854
# TotalBsmtSF                  1         0.06854
# BsmtFullBath                 2         0.13708
# BsmtHalfBath                 2         0.13708
# GarageCars                   1         0.06854
# GarageArea                   1         0.06854

# %%
novos_dados['BsmtHalfBath'].fillna(0, inplace=True)
novos_dados['BsmtFullBath'].fillna(0, inplace=True)
novos_dados['GarageCars'].fillna(0, inplace=True)

# %%
for col in ['BsmtFinSF1', 'BsmtFinSF2', 'TotalBsmtSF', 'BsmtUnfSF', 'GarageArea']:
    median_value = novos_dados[col].median()
    novos_dados[col].fillna(median_value, inplace=True)

# %%
novos_numericas = novos_dados.select_dtypes(include=[np.number])

# Contar valores ausentes por coluna categórica
missing_numeric = novos_numericas.isna().sum()

# Filtrar apenas as colunas com valores ausentes
missing_numeric = missing_numeric[missing_numeric > 0]

# Calcular o percentual de valores ausentes
percentual_missing = (missing_numeric / len(novos_numericas)) * 100

# Combinar os dados em um DataFrame para facilitar a visualização
missing_summary = pd.DataFrame({
    'Valores Ausentes': missing_numeric,
    'Percentual (%)': percentual_missing
})

print(missing_summary)
# Out:
# Empty DataFrame
# Columns: [Valores Ausentes, Percentual (%)]
# Index: []

# %%
novos_categoricas  = novos_dados.select_dtypes(include=['object','category'])

# Contar valores ausentes por coluna categórica
missing_categ = novos_dados.isna().sum()

# Filtrar apenas as colunas com valores ausentes
missing_categ = missing_categ[missing_categ > 0]

# Calcular o percentual de valores ausentes
percentual_missing = (missing_categ / len(novos_dados)) * 100

# Combinar os dados em um DataFrame para facilitar a visualização
missing_summary = pd.DataFrame({
    'Valores Ausentes': missing_categ,
    'Percentual (%)': percentual_missing
})

print(missing_summary)
# Out:
#               Valores Ausentes  Percentual (%)
# MSZoning                     4        0.274160
# Alley                     1352       92.666210
# Utilities                    2        0.137080
# Exterior1st                  1        0.068540
# Exterior2nd                  1        0.068540
# MasVnrType                 894       61.274846
# BsmtQual                    44        3.015764
# BsmtCond                    45        3.084304
# BsmtExposure                44        3.015764
# BsmtFinType1                42        2.878684
# BsmtFinType2                42        2.878684
# KitchenQual                  1        0.068540
# Functional                   2        0.137080
# FireplaceQu                730       50.034270
# GarageType                  76        5.209047
# GarageFinish                78        5.346127
# GarageQual                  78        5.346127
# GarageCond                  78        5.346127
# PoolQC                    1456       99.794380
# ...

# %%
novos_dados.drop(columns = ['Alley','MasVnrType','FireplaceQu','PoolQC','Fence','MiscFeature'],inplace=True)

# %%
novos_dados.reset_index(drop=True)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             20       RH         80.0    11622   Pave      Reg         Lvl
# 1             20       RL         81.0    14267   Pave      IR1         Lvl
# 2             60       RL         74.0    13830   Pave      IR1         Lvl
# 3             60       RL         78.0     9978   Pave      IR1         Lvl
# 4            120       RL         43.0     5005   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 1454         160       RM         21.0     1936   Pave      Reg         Lvl
# 1455         160       RM         21.0     1894   Pave      Reg         Lvl
# 1456          20       RL        160.0    20000   Pave      Reg         Lvl
# 1457          85       RL         62.0    10441   Pave      Reg         Lvl
# 1458          60       RL         74.0     9627   Pave      Reg         Lvl
#
# ...

# %%
novos_dados.shape
# Out:
# (1459, 73)

# %%
cols = ['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','GarageType','GarageFinish','GarageQual','GarageCond']

# Substituir valores missing pela moda de cada coluna
for col in cols:
    moda = X_train_categoricas[col].mode()[0]  # Calcula a moda (valor mais frequente)
    novos_dados[col].fillna(moda,inplace=True) # Substitui no Test para aplicação do modelo

# Verificar se os valores missing foram preenchidos
print(novos_dados[cols].isnull().sum())
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
missing = novos_dados.isna().sum()

missing = missing[missing > 0]

missing
# Out:
# MSZoning       4
# Utilities      2
# Exterior1st    1
# Exterior2nd    1
# KitchenQual    1
# Functional     2
# SaleType       1
# dtype: int64

# %%
# Lista das variáveis categóricas com valores ausentes
categorical_missing = ['MSZoning', 'Exterior1st', 'Exterior2nd', 'KitchenQual', 'Functional', 'SaleType','Utilities']

# Preenchendo com a moda do treino
for col in categorical_missing:
    mode_value = novos_dados[col].mode()[0]  # Calculando a moda do Test
    novos_dados[col].fillna(mode_value, inplace=True)

# %%
missing = novos_dados.isna().sum()

missing = missing[missing > 0]

missing
# Out:
# Series([], dtype: int64)

# %%
# Selecionar variáveis numéricas, excluindo 'SalePrice'
numerical_columns = X_train.select_dtypes(include=['float64', 'int64']).columns.tolist()
numerical_columns = [col for col in numerical_columns if col != 'SalePrice']

# Função para substituir os outliers pelo limite calculado com IQR
def replace_outliers_with_limits_IQR(df, col, lower_limit, upper_limit):
    df[col] = np.where(df[col] < lower_limit, lower_limit, df[col])
    df[col] = np.where(df[col] > upper_limit, upper_limit, df[col])
    return df

# Calcular os limites IQR para X_train
outlier_limits = {}
for col in numerical_columns:
    Q1 = X_train[col].quantile(0.25)
    Q3 = X_train[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    
    # Armazenar limites
    outlier_limits[col] = (lower_limit, upper_limit)

# Aplicar os limites ao X_train e X_test
for col in numerical_columns:
    lower_limit, upper_limit = outlier_limits[col]
    novos_dados = replace_outliers_with_limits_IQR(novos_dados, col, lower_limit, upper_limit)
# Mostrar as primeiras linhas após o tratamento
print(novos_dados.head())
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    4.517101       RH         80.0  11622.0   Pave      Reg         Lvl
# 1    4.517101       RL         81.0  14267.0   Pave      IR1         Lvl
# 2    4.517101       RL         74.0  13830.0   Pave      IR1         Lvl
# 3    4.517101       RL         78.0   9978.0   Pave      IR1         Lvl
# 4    4.517101       RL         43.0   5005.0   Pave      IR1         HLS
#
#   Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0    AllPub    Inside       Gtl  ...    0.000000             0         0
# 1    AllPub    Corner       Gtl  ...    3.910438             0         0
# 2    AllPub    Inside       Gtl  ...    3.910438             0         0
# 3    AllPub    Inside       Gtl  ...    3.910438             0         0
# 4    AllPub    Inside       Gtl  ...    3.910438             0         0
#
#   ScreenPorch PoolArea  MiscVal  MoSold  YrSold  SaleType SaleCondition
# ...

# %%
novos_dados.reset_index(drop=True)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0       4.517101       RH         80.0  11622.0   Pave      Reg         Lvl
# 1       4.517101       RL         81.0  14267.0   Pave      IR1         Lvl
# 2       4.517101       RL         74.0  13830.0   Pave      IR1         Lvl
# 3       4.517101       RL         78.0   9978.0   Pave      IR1         Lvl
# 4       4.517101       RL         43.0   5005.0   Pave      IR1         HLS
# ...          ...      ...          ...      ...    ...      ...         ...
# 1454    4.517101       RM         31.5   1936.0   Pave      Reg         Lvl
# 1455    4.517101       RM         31.5   1894.0   Pave      Reg         Lvl
# 1456    4.517101       RL        107.5  17866.5   Pave      Reg         Lvl
# 1457    4.517101       RL         62.0  10441.0   Pave      Reg         Lvl
# 1458    4.517101       RL         74.0   9627.0   Pave      Reg         Lvl
#
# ...

# %%
novos_dados.drop(columns=['MiscVal','PoolArea','ScreenPorch','3SsnPorch','EnclosedPorch','KitchenAbvGr','BsmtHalfBath','LowQualFinSF','BsmtFinSF2'],inplace=True)

# %%
novos_dados.shape
# Out:
# (1459, 64)

# %%
# Variáveis de interesse
variables_of_interest = ['MSSubClass', 'MasVnrArea', 'WoodDeckSF', 'OpenPorchSF']

# Criar o PowerTransformer para Yeo-Johnson
pt = PowerTransformer(method='yeo-johnson')

# Dicionário para armazenar os lambdas de Box-Cox
boxcox_lambdas = {}

# Dicionário para armazenar os objetos PowerTransformer para cada variável
power_transformers = {}

# Processar as variáveis de interesse
for col in variables_of_interest:
    # Verificar se a variável tem apenas valores positivos em X_train
    if (X_train[col] > 0).all():  # Para Box-Cox, todos os valores devem ser positivos
        
        novos_dados[col] = boxcox(novos_dados[col],lmbda=lambda_)
        print(f'Box-Cox aplicado na variável {col} nos Novos Dados com lambda: {lambda_}')
        
    else:
        pt_fitted = pt.fit(X_train[[col]])
        # Aplicar a mesma transformação em X_test com o PowerTransformer ajustado
        novos_dados[col] = pt_fitted.transform(novos_dados[[col]])
        print(f'Yeo-Johnson aplicado na variável {col} no Novos Dados')
# Out:
# Box-Cox aplicado na variável MSSubClass nos Novos Dados com lambda: -0.12268687316042722
# Yeo-Johnson aplicado na variável MasVnrArea no Novos Dados
# Yeo-Johnson aplicado na variável WoodDeckSF no Novos Dados
# Yeo-Johnson aplicado na variável OpenPorchSF no Novos Dados

# %%
novos_dados.drop(columns=['TotRmsAbvGrd','GarageYrBlt','GarageCars','OverallQual'],inplace=True)

# %%
novos_dados.shape
# Out:
# (1459, 60)

# %%
novos_dados.drop(columns=['Utilities', 'LandSlope', 'Street','RoofMatl','Condition2'],inplace=True)

# %%
novos_dados.shape
# Out:
# (1459, 55)

# %%
novos_dados.reset_index(drop=True)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour  \
# 0       1.376613       RH         80.0  11622.0      Reg         Lvl
# 1       1.376613       RL         81.0  14267.0      IR1         Lvl
# 2       1.376613       RL         74.0  13830.0      IR1         Lvl
# 3       1.376613       RL         78.0   9978.0      IR1         Lvl
# 4       1.376613       RL         43.0   5005.0      IR1         HLS
# ...          ...      ...          ...      ...      ...         ...
# 1454    1.376613       RM         31.5   1936.0      Reg         Lvl
# 1455    1.376613       RM         31.5   1894.0      Reg         Lvl
# 1456    1.376613       RL        107.5  17866.5      Reg         Lvl
# 1457    1.376613       RL         62.0  10441.0      Reg         Lvl
# 1458    1.376613       RL         74.0   9627.0      Reg         Lvl
#
#      LotConfig Neighborhood Condition1 BldgType  ... GarageArea  GarageQual  \
# ...

# %%
# Verificar se há valores ausentes no DataFrame
print(novos_dados.isnull().any().any())
# Out:
# False

# %%
novos_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 55 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   float64
#  1   MSZoning       1459 non-null   object
#  2   LotFrontage    1459 non-null   float64
#  3   LotArea        1459 non-null   float64
#  4   LotShape       1459 non-null   object
#  5   LandContour    1459 non-null   object
#  6   LotConfig      1459 non-null   object
#  7   Neighborhood   1459 non-null   object
#  8   Condition1     1459 non-null   object
#  9   BldgType       1459 non-null   object
#  10  HouseStyle     1459 non-null   object
#  11  OverallCond    1459 non-null   float64
#  12  YearBuilt      1459 non-null   float64
#  13  YearRemodAdd   1459 non-null   float64
#  14  RoofStyle      1459 non-null   object
#  15  Exterior1st    1459 non-null   object
#  16  Exterior2nd    1459 non-null   object
# ...

# %%
# Carregar o OneHotEncoder, StandardScaler e o modelo
encoder = joblib.load('OneHotEncoder.pkl')
scaler = joblib.load('standard_scaler.pkl')
model = joblib.load('modelo_regressao_ridge_melhorado.pkl')

# %%
# Aplicando a transformação no conjunto de teste
novos_dados_encoded = encoder.transform(novos_dados)

# Aplicando o StandardScaler no conjunto de teste
novos_dados_scaled = scaler.transform(novos_dados_encoded)

# %%
# Aplicar o modelo no conjunto de teste transformado
SalePrice_boxcox = model.predict(novos_dados_scaled)

# %%
# Criar um novo DataFrame com as colunas 'ID' e 'SalePrice_boxcox'
resultado_previo = pd.DataFrame({
    'ID': id_novos_dados,  # Variável que contém os valores originais da coluna ID
    'SalePrice_boxcox': SalePrice_boxcox  # Coluna com as predições
})

# Visualizar as primeiras linhas do novo DataFrame
print(resultado_previo.head())
# Out:
#      ID  SalePrice_boxcox
# 0  1461          7.738219
# 1  1462          7.861833
# 2  1463          7.943684
# 3  1464          7.955004
# 4  1465          7.933906

# %%
from scipy.special import inv_boxcox

# Suponha que você conhece o valor de lambda usado na transformação Box-Cox
lambda_value = fitted_lambda  # Substitua pelo valor real do lambda usado na transformação

# Aplicar a inversão da transformação Box-Cox
resultado_previo['SalePrice'] = inv_boxcox(resultado_previo['SalePrice_boxcox'], lambda_value)

# Visualizar as primeiras linhas após a destransformação
print(resultado_previo.head())

# Remover a coluna 'SalePrice_boxcox'
resultado_previo = resultado_previo.drop('SalePrice_boxcox', axis=1)

# Opcional: Salvar o resultado final
resultado_previo.to_csv('sample_submission.csv', index=False)
# Out:
#      ID  SalePrice_boxcox      SalePrice
# 0  1461          7.738219  128957.929788
# 1  1462          7.861833  175757.222383
# 2  1463          7.943684  216644.376806
# 3  1464          7.955004  223062.014020
# 4  1465          7.933906  211260.907469

# %%
print(resultado_previo)
# Out:
#         ID      SalePrice
# 0     1461  128957.929788
# 1     1462  175757.222383
# 2     1463  216644.376806
# 3     1464  223062.014020
# 4     1465  211260.907469
# ...    ...            ...
# 1454  2915   94123.829994
# 1455  2916   93943.990222
# 1456  2917  188069.165141
# 1457  2918  152768.724574
# 1458  2919  229171.847726
#
# [1459 rows x 2 columns]
